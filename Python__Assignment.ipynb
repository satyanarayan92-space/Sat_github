# %% [markdown]
# <a href="https://colab.research.google.com/github/satyanarayan92-space/Sat_github/blob/main/Python__Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Accept a student's name and display it in uppercase
student_name = input("Enter student's name:")
print("Uppercase Name:", student_name.upper())
# Out:
# Enter student's name:satya
# Uppercase Name: SATYA

# %%
# Q2. Accept a city name and display Original, Uppercase, Lowercase, and Title Case
city_name = input("Enter city name:")

print("Original Name:", city_name)
print("Uppercase:", city_name.upper())
print("Lowercase:", city_name.lower())
print("Title Case", city_name.title())
# Out:
# Enter city name:berhampur
# Original Name: berhampur
# Uppercase: BERHAMPUR
# Lowercase: berhampur
# Title Case Berhampur

# %%
# Q3. Accept a string and display its total length
text  = input("Enter a string: ")
print("Length of string:", len(text))
# Out:
# Enter a string: satya
# Length of string: 5

# %%
# Q4. Accept a string and display first charecter and last charecter
text = input("Enter a string:")

print("first charecter:", text[0])
print("Last charecter:", text[-1])
# Out:
# Enter a string:satya
# first charecter: s
# Last charecter: a

# %%
# Q5. count the number of times the letter 'a' appears in a string
text = input("Enter a string:")

print("Number of times 'a' appears:", text.count('a'))
# Out:
# Enter a string:aditya
# Number of times 'a' appears: 2

# %%
# Q6. Replace the word "Python" with "AI" in a sentence
sentence = input("Enter a sentence:")

new_sentence = sentence.replace("Python", "AI")
print("Updated Sentence:", new_sentence)
# Out:
# Enter a sentence:Python is future of IT.
# Updated Sentence: AI is future of IT.

# %%
# Q7. Check whether an email address ends with @gmail.com
email_address = input("Enter email address: ")
if email_address.endswith("@gmail.com"):
  print("Valid Gmail Address")
else:
    print("Not a Gmail Address")
# Out:
# Enter email address: satya92@gmail.com
# Valid Gmail Address

# %%
# Q8. Check whether the input contains only digits
user_input = input("Enter a value: ")

if user_input.isdigit():
  print("Contains only digits")
else:
  print("Does not contain only digits")
# Out:
# Enter a value: Sa8t6y5a8
# Does not contain only digits

# %%
# Q9. Check whether the input contains only alphabets
user_input = input("Enter a value: ")
if user_input.isalpha():
    print("Contains only alphabets")
else:
  print("Does not contain only alphabets")
# Out:
# Enter a value: satya
# Contains only alphabets

# %%
# Q10. Split the string into a list
fruit_string = "Apple,Mango,Banana,Orange"

fruit_list = fruit_string.split(",")
print("List:",fruit_list)
# Out:
# List: ['Apple', 'Mango', 'Banana', 'Orange']

# %%
# Q11. Check whether a person is eligible to vote
age = int(input("Enter age: "))

if age >= 18:
  print("Eligible to vote")
else:
  print("Not eligible to vote")
# Out:
# Enter age: 23
# Eligible to vote

# %%
# Q12. Check whether a number is Positive, Negative, or Zero

number = int(input("Enter a number: "))

if number > 0:
  print("Positive")
elif number < 0:
  print("Negative")
else:
  print("Zero")
# Out:
# Enter a number: -45
# Negative

# %%
# Q13. Find the greater number between two numbers
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))

if num1 > num2:
  print("Greater number:", num1)
else:
  print("Greater number:", num2)
# Out:
# Enter first number: 45
# Enter second number: 56
# Greater number: 56

# %%
# Q14. Assign grades based on marks

marks = int(input("Enter marks: "))

if 90 <= marks <= 100:
  print("Grade A")
elif 75 <= marks <= 89:
  print("Grade B")
elif 50 <= marks <= 74:
  print("Grade C")
else:
    print("Fail")
# Out:
# Enter marks: 89
# Grade B

# %%
# Q15. Check whether a number is Even or Odd

number = int(input("Enter a number: "))

if number % 2 == 0:
  print("Even")
else:
  print("Odd")
# Out:
# Enter a number: 45
# Odd

# %%
# Q16. Check whether a password is strong or weak
password = input("Enter password: ")

if len(password) >= 8:
  print("Strong password")
else:
  print("Weak password")
# Out:
# Enter password: satya123
# Strong password

# %%
# Q17. Check whether a year is a leap Year
year = int(input("Enter year: "))

if year % 4 == 0:
  print("Leap Year")
else:
  print("Not a Leap Year")
#
# Out:
# Enter year: 2001
# Not a Leap Year

# %%
# Q18. Find the largest among three numbers

num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
num3 = int(input("Enter third number: "))

if num1 >= num2 and num1 >= num3:
  print("Largest number:", num1)
elif num2 >= num1 and num2 >= num3:
  print("Largest number:", num2)
else:
  print("Largest number:", num3)
# Out:
# Enter first number: 45
# Enter second number: 56
# Enter third number: 28
# Largest number: 56

# %%
# Q19. Validate login credentials

username = input("Enter username: ")
password = input("Enter password: ")

if username == "admin" and password == "12345":
  print("Valid credentials")
else:
  print("Invalid credentials")
# Out:
# Enter username: satya92-space
# Enter password: satya1234
# Invalid credentials

# %%
num1 = int(input("Enter first number: "))
num2 = int(input("Enter second number: "))
operator = input("Enter operator: ")

if operator == "+":
  print("Addition:", num1 + num2)
elif operator == "-":
  print("Subtraction:", num1 - num2)
elif operator == "*":
  print("Multiplication:", num1 * num2)
elif operator == "/":
  print("Division:", num1 / num2)
else:
  print("Invalid operator")
# Out:
# Enter first number: 45
# Enter second number: 56
# Enter operator: *
# Multiplication: 2520
